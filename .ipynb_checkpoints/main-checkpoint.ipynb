# %%
import weight_tracker_functions as wtf
import exercise_tracker_functions as etf

# %%
def exercise_function():
    tracker = etf.FitnessTracker()
    Loop = False
    while not Loop: 
        print("""
        (1): Add Exercise To Workout
        (2): Display Exercises In Workout
        (3): Clear Exercise List
        (4): Export to CSV
        (b): Back
        """)
        option = input("Choose an Option:")
        if option == "1":
            name = input("Exercise Name")
            sets = int(input("Sets:"))
            name_list = []
            sets_list = []
            reps_list = []
            weight_list = []
            for count in range(sets):
                weight = int(input("Weight(kg):"))
                reps = int(input("For Reps: "))
                name_list.append(name)
                sets_list.append(count + 1)
                reps_list.append(reps)
                weight_list.append(weight)
            tracker.add_exercise(name_list, weight_list, reps_list, sets_list)
        if option == "2":
            tracker.display_exercises()
        if option == "3":
            tracker.clear_exercises()
        if option == "b":
            Loop = True
        if option == "4":
            tracker.export_to_csv()

# %%
def weight_function():
    loop = False
    tracker = wtf.WeightTracker()
    tracker.check_csv()

    while not loop:
        print("""
        (1): View Weight Tracker
        (2): Add Todays Weight
        (3): Remove A Data Entry
        (4): Open Database 
        (b): Back
        """)
        option = input("Please Chose an Option: ")

        if option == "1":
            tracker.view_weight()

        if option == "2":
            weight_input = input("Input Todays Weight: ")
            tracker.update_csv(weight_input)

        if option == "3":
            data_preview = pd.read_csv("data/weight_tracker.csv")
            first_row = 0
            last_row = len(data_preview)-1
            print(data_preview)
            option_3_loop = False
            while not option_3_loop:
                row_to_remove = int(input("Please input the row to be removed: "))
                if first_row <= row_to_remove <= last_row:
                    row = row_to_remove
                    option_3_loop = True
                else:
                    print("Incorrect Input")
            tracker.remove_entry(row)
            tracker.view_weight()

        if option == "4":
            tracker.open_database()

        if option == "b":
            loop = True

# %%
def main():
    main_loop = False 
    
    while not main_loop:
        print(
            """
            (1): Weight Tracker
            (2): Exercise Tracker
            (q): Quit
            """)
        option = input("Please input an operator: ")
        
        if option == "1":
            weight_function()
        if option == "2":
            exercise_function()
        if option == "q":
            main_loop = True

# %%
main()
# Out:
#             (1): Weight Tracker
#             (2): Exercise Tracker
#             (q): Quit
#
# Please input an operator: 2
#
#         (1): Add Exercise To Workout
#         (2): Display Exercises In Workout
#         (3): Clear Exercise List
#         (4): Export to CSV
#         (b): Back
#
# Choose an Option:1
# Exercise NameSquat
# Sets:8
# Weight(kg):70
# For Reps: 5
# Weight(kg):100
# For Reps: 3
# Weight(kg):100
# For Reps: 3
# Weight(kg):100
# For Reps: 3
# Weight(kg):120
# For Reps: 1
# Weight(kg):130
# For Reps: 1
# Weight(kg):135
# For Reps: 1
# Weight(kg):140
# For Reps: 1
#
#         (1): Add Exercise To Workout
#         (2): Display Exercises In Workout
#         (3): Clear Exercise List
#         (4): Export to CSV
#         (b): Back
#
# Choose an Option:1
# Exercise NameBulgarian Split Squat
# Sets:4
# Weight(kg):18
# For Reps: 8
# Weight(kg):18
# For Reps: 6
# Weight(kg):18
# For Reps: 6
# Weight(kg):18
# For Reps: 8
#
#         (1): Add Exercise To Workout
#         (2): Display Exercises In Workout
#         (3): Clear Exercise List
#         (4): Export to CSV
#         (b): Back
#
# Choose an Option:1
# Exercise NameGoblin Squat
# Sets:4
# Weight(kg):30
# For Reps: 8
# Weight(kg):30
# For Reps: 8
# Weight(kg):30
# For Reps: 6
# Weight(kg):30
# For Reps: 6
#
#         (1): Add Exercise To Workout
#         (2): Display Exercises In Workout
#         (3): Clear Exercise List
#         (4): Export to CSV
#         (b): Back
#
# Choose an Option:1
# Exercise NameGlute Bridge
# Sets:4
# Weight(kg):0
# For Reps: 10
# Weight(kg):0
# For Reps: 10
# Weight(kg):0
# For Reps: 10
# Weight(kg):0
# For Reps: 10
#
#         (1): Add Exercise To Workout
#         (2): Display Exercises In Workout
#         (3): Clear Exercise List
#         (4): Export to CSV
#         (b): Back
#
# Choose an Option:1
# Exercise NameCalf Raise
# Sets:4
# Weight(kg):18
# For Reps: 20
# Weight(kg):18
# For Reps: 20
# Weight(kg):18
# For Reps: 20
# Weight(kg):18
# For Reps: 20
#
#         (1): Add Exercise To Workout
#         (2): Display Exercises In Workout
#         (3): Clear Exercise List
#         (4): Export to CSV
#         (b): Back
#
# Choose an Option:1
# Exercise NameRDL
# Sets:3
# Weight(kg):60
# For Reps: 5
# Weight(kg):80
# For Reps: 5
# Weight(kg):80
# For Reps: 5
#
#         (1): Add Exercise To Workout
#         (2): Display Exercises In Workout
#         (3): Clear Exercise List
#         (4): Export to CSV
#         (b): Back
#
# Choose an Option:2
#                      Name  Set  Reps  Weight
# 0                   Squat    1     5      70
# 1                   Squat    2     3     100
# 2                   Squat    3     3     100
# 3                   Squat    4     3     100
# 4                   Squat    5     1     120
# 5                   Squat    6     1     130
# 6                   Squat    7     1     135
# 7                   Squat    8     1     140
# 8   Bulgarian Split Squat    1     8      18
# 9   Bulgarian Split Squat    2     6      18
# 10  Bulgarian Split Squat    3     6      18
# 11  Bulgarian Split Squat    4     8      18
# 12           Goblin Squat    1     8      30
# 13           Goblin Squat    2     8      30
# 14           Goblin Squat    3     6      30
# 15           Goblin Squat    4     6      30
# 16           Glute Bridge    1    10       0
# 17           Glute Bridge    2    10       0
# 18           Glute Bridge    3    10       0
# 19           Glute Bridge    4    10       0
# 20             Calf Raise    1    20      18
# 21             Calf Raise    2    20      18
# 22             Calf Raise    3    20      18
# 23             Calf Raise    4    20      18
# 24                    RDL    1     5      60
# 25                    RDL    2     5      80
# 26                    RDL    3     5      80
#
#         (1): Add Exercise To Workout
#         (2): Display Exercises In Workout
#         (3): Clear Exercise List
#         (4): Export to CSV
#         (b): Back
#
# Choose an Option:4
#
#         (1): Add Exercise To Workout
#         (2): Display Exercises In Workout
#         (3): Clear Exercise List
#         (4): Export to CSV
#         (b): Back
#
# Choose an Option:b
#
#             (1): Weight Tracker
#             (2): Exercise Tracker
#             (q): Quit
#
# Please input an operator: q
